# %% [markdown]
# **5.(a)**
#
# (1). The objective function: $J(\theta)=\sum_{i=1}^n (\theta^T \hat{x}^{(i)}-y^{(i)})^2$
#
# (2). The batch GD update rule: $\theta = \theta-\alpha \sum_{i=1}^n (\theta^T \hat{x}^{(i)}-y^{(i)})\hat{x}^{(i)}$

# %% [markdown]
# **(b)**
#
# ![deg3.png](attachment:78fc7a9a-7008-4858-a52f-bdb1f4e46317.png)

# %% [markdown]
# **(c)**
#
# ![poly.png](attachment:819f4914-f02e-4f27-ba0c-37dd27e02a67.png)

# %% [markdown]
# **(d)**
#
# ![sine.png](attachment:a137c2de-519a-42d9-b7b6-05186b755f53.png)
#
# **(e)**
#
# ![overfit.png](attachment:c250749c-4ad4-4086-bfd6-d9c6111380f0.png)
