# %% [markdown]
# **(a)**
#
# ![p02a.png](attachment:98aaff8f-583c-4089-97d9-59fed87e2ee2.png)
#
# **(b)**
#
# ![p02b.png](attachment:689f43e5-2220-4745-ae60-8e4de909af4e.png)

# %% [markdown]
# **(c)**

# %% [markdown]
# **(f)**
#
# ![p02f.png](attachment:36ec2a8e-09d2-4092-ba0b-249f6b2e2071.png)
